# %%
# Necessary imports
import glob
import pandas as pd
import urllib.request
import imageio
import os
import numpy as np
# Imports
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense, Concatenate 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D, Conv2DTranspose
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras import initializers
from sklearn.metrics import mean_squared_error

import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt
from urllib.request import urlopen
# Out:
# 2023-04-24 23:07:56.145792: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 23:07:56.837515: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
# Generation resolution - Must be square 
# Training data is also scaled to this.
GENERATE_RES = 2 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100
EMBEDDING_SIZE = 200

# Configuration
#DATA_PATH = train_images_path
MODEL_PATH = "./Data/datasets/flowers/model"
EPOCHS = 50
BATCH_SIZE = 64
BUFFER_SIZE = 4000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 64px square images.

# %%
caption_embeddings = np.load('./Data/datasets/flowers/text_c10/caption_embeddings.npy')
print(caption_embeddings.shape)
image_binary_path = "./Data/datasets/flowers/images/npy64/"
images = os.listdir(image_binary_path)
# Out:
# (8189, 200)

# %%
# Creating a list of all the preprocessed images
final_images = np.load(image_binary_path + images[0])
for i in images[1:]:
    try:
        final_images = np.concatenate([final_images,np.load(image_binary_path + i)],axis = 0)
    except:
        pass
    
print(final_images.shape)
# Out:
# (8100, 64, 64, 3)

# %%
df_captions = pd.read_csv("./output.csv")
captions = list(df_captions.Text)

# %%
len(captions)
# Out:
# 8189

# %%
save_images_captions = captions[:28].copy()
save_images_embeddings = np.copy(caption_embeddings[:28])
save_images_npy = np.copy(final_images[:28])

# %%
caption_embeddings = caption_embeddings[:final_images.shape[0]]
caption_embeddings.shape
# Out:
# (8100, 200)

# %%
p = np.random.permutation(len(final_images))
final_images_shuffled = final_images[p]
final_embeddings_shuffled = caption_embeddings[p]
print(final_images_shuffled.shape)
# Out:
# (8100, 64, 64, 3)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices({'images': final_images,
                                                    'embeddings': caption_embeddings}).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
# Out:
# 2023-04-24 23:08:01.109777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46662 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:81:00.0, compute capability: 8.6

# %% [markdown]
# ### Big Gan

# %%
# Size of the random noise vector
SEED_SIZE = 100

# Size of the embedding vector for the captions
EMBEDDING_SIZE = 200

# Number of channels in the generated images
IMAGE_CHANNELS = 3

def build_generator_func(seed_size, embedding_size, channels):
    noise_input = layers.Input(shape=(seed_size,))
    embedding_input = layers.Input(shape=(embedding_size,))

    # Concatenate the noise and embedding inputs
    concatenated_inputs = layers.Concatenate()([noise_input, embedding_input])

    # Project and reshape the inputs
    x = layers.Dense(4 * 4 * 256)(concatenated_inputs)
    x = layers.Reshape((4, 4, 256))(x)

    # Block 1
    x = layers.Conv2DTranspose(128, 5, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    # Block 2
    x = layers.Conv2DTranspose(64, 5, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    # Block 3
    x = layers.Conv2DTranspose(32, 5, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    # Output block
    output = layers.Conv2DTranspose(channels, 5, strides=2, padding="same", activation="tanh")(x)

    return tf.keras.models.Model([noise_input, embedding_input], output)


def build_discriminator_func(input_shape, embedding_size):
    image_input = layers.Input(shape=input_shape)
    embedding_input = layers.Input(shape=(embedding_size,))

    # Block 1
    x = layers.Conv2D(64, 5, strides=2, padding="same")(image_input)
    x = layers.LeakyReLU()(x)

    # Block 2
    x = layers.Conv2D(128, 5, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    # Block 3
    x = layers.Conv2D(256, 5, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    # Global average pooling
    x = layers.GlobalAveragePooling2D()(x)

    # Concatenate with the embedding input
    x = layers.Concatenate()([x, embedding_input])

    # Output block
    output = layers.Dense(1, activation="sigmoid")(x)

    return tf.keras.models.Model([image_input, embedding_input], output)


# Build the generator and discriminator models
generator = build_generator_func(SEED_SIZE, EMBEDDING_SIZE, IMAGE_CHANNELS)
discriminator = build_discriminator_func((64, 64, IMAGE_CHANNELS), EMBEDDING_SIZE)

generator = build_generator_func(SEED_SIZE,EMBEDDING_SIZE, IMAGE_CHANNELS)
# Sample output from the Generator
noise = tf.random.normal([1, 100])
generated_image = generator((noise,caption_embeddings[5].reshape(1,200)), training=False)
plt.imshow(generated_image[0, :, :, 0])
# Out:
# 2023-04-24 23:08:02.865554: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-04-24 23:08:02.972699: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-04-24 23:08:03.595950: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)
decision = discriminator((generated_image,caption_embeddings[5].reshape(1,200)))
print(decision)
# Out:
# tf.Tensor([[0.44647765]], shape=(1, 1), dtype=float32)

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy()
def discriminator_loss(real_image_real_text, fake_image_real_text, real_image_fake_text):
    real_loss = cross_entropy(tf.random.uniform(real_image_real_text.shape,0.8,1.0), real_image_real_text)
    fake_loss = (cross_entropy(tf.random.uniform(fake_image_real_text.shape,0.0,0.2), fake_image_real_text) + 
                 cross_entropy(tf.random.uniform(real_image_fake_text.shape,0.0,0.2), real_image_fake_text))/2

    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(learning_rate=2.0e-4,beta_1 = 0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate=2.0e-4,beta_1 = 0.5)

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images,captions,fake_captions):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE],dtype=tf.float32)

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator((seed,captions), training=True)
    real_image_real_text = discriminator((images,captions), training=True)
    real_image_fake_text = discriminator((images,fake_captions), training=True)
    fake_image_real_text = discriminator((generated_images,captions), training=True)

    gen_loss = generator_loss(fake_image_real_text)
    disc_loss = discriminator_loss(real_image_real_text, fake_image_real_text, real_image_fake_text)
    # print(gen_loss)
    # print(disc_loss)

    gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def save_images(cnt,noise,embeds):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)

  generated_images = generator.predict((noise,embeds))

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_images[image_count] * 255
        image_count += 1

          
  output_path = "./Data/datasets/output"
  if not os.path.exists(output_path):
    os.makedirs(output_path)

  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
# Function that executes trianing process
def train(train_dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  fixed_embed = save_images_embeddings

  start = time.time()

  for epoch in range(epochs):
    print("epoch start...")
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for batch in train_dataset[:-1]:
      # train_batch = training_data[BATCH_SIZE*image_batch : BATCH_SIZE*image_batch + BATCH_SIZE]
      # caption_batch = captions[BATCH_SIZE*image_batch : BATCH_SIZE*image_batch + BATCH_SIZE]
      train_batch = batch['images']
      caption_batch = batch['embeddings']
      
      fake_caption_batch = np.copy(caption_batch)
      np.random.shuffle(fake_caption_batch)
      
      t = train_step(train_batch,caption_batch,fake_caption_batch)
      # print(t)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])
      # if image_batch%50 == 0:
      #   print(image_batch)
      # print("here")
    print("now")
    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print(f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss}, {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed,fixed_embed)
    
    generator.save(os.path.join(MODEL_PATH,"text_to_image_generator_biggan_character.h5"))
    discriminator.save(os.path.join(MODEL_PATH,"text_to_image_disc_biggan_character.h5"))
    print("model saved")

  elapsed = time.time()-start
  print ('Training time:', hms_string(elapsed))

# %%
train(list(train_dataset.as_numpy_iterator()), 2500)
# Out:
# 2023-04-24 23:08:04.526879: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [8100,64,64,3]
# 	 [[{{node Placeholder/_1}}]]
# 2023-04-24 23:08:04.527097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [8100,64,64,3]
# 	 [[{{node Placeholder/_1}}]]
# epoch start...
# 2023-04-24 23:08:06.533536: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f279cc86b00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-04-24 23:08:06.533563: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-04-24 23:08:06.536737: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-04-24 23:08:06.587830: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-24 23:08:06.646078: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# now
# Epoch 1, gen loss=0.7965664267539978,disc loss=1.3539966344833374, 0:00:05.88
# 1/1 [==============================] - 0s 223ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 
ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2492, gen loss=1.9914379119873047,disc loss=1.1718496084213257, 0:00:01.49
# 1/1 [==============================] - 0s 14ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2493, gen loss=1.9627023935317993,disc loss=1.1721609830856323, 0:00:01.50
# 1/1 [==============================] - 0s 14ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2494, gen loss=1.9291044473648071,disc loss=1.1724302768707275, 0:00:01.50
# 1/1 [==============================] - 0s 13ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2495, gen loss=1.9456398487091064,disc loss=1.1724311113357544, 0:00:01.51
# 1/1 [==============================] - 0s 14ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2496, gen loss=1.9591708183288574,disc loss=1.1747725009918213, 0:00:01.51
# 1/1 [==============================] - 0s 14ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2497, gen loss=1.9564273357391357,disc loss=1.1761714220046997, 0:00:01.50
# 1/1 [==============================] - 0s 14ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2498, gen loss=1.9340356588363647,disc loss=1.1748112440109253, 0:00:01.49
# 1/1 [==============================] - 0s 13ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2499, gen loss=1.939565658569336,disc loss=1.1728315353393555, 0:00:01.50
# 1/1 [==============================] - 0s 13ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2500, gen loss=1.9742869138717651,disc loss=1.1711746454238892, 0:00:01.49
# 1/1 [==============================] - 0s 14ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# Training time: 1:08:22.96

# %%
generator.load_weights((os.path.join(MODEL_PATH,"text_to_image_generator_biggan_character.h5")))
discriminator.load_weights((os.path.join(MODEL_PATH,"text_to_image_disc_biggan_character.h5")))

# %%
print(save_images_embeddings.shape)
# Printing the captions
save_images_captions
# Out:
# (28, 200)
# ['this is a large flower with red and yellow petals and a brown stem.\nthis flower has petals that are red with yellow tips and many purple stamen.\nthis is a flower with petals that are red toward the center and yellow around the edges.\nthis flower has petals that are red with yellow tips\nthis flower is pink and yellow in color, with petals that are yellow near the tips.\nthe stamen are dark red and cover a round center of the flower, surrounded by petals that are dark pink closest to the center and bright yellow furthest from the center of the flower.\nthis flower has many petals which are yellow on the edges and red near the middle.\nthis flower has red petals with yellow tips and purple stamen\nthis flower is pink and yellow in color, and has petals that are multi colored.\nthere are many dark red filaments surrounded by mostly red petals that turn to yellow at their tip.\n',
#  'the petals on this plant are thin and are red with yellow tips\nthis flower has petals that are red with yellowtips\nthe petals are narrow and pointed and primarily orange in color but with yellow tips and the stamen and stigma are brown.\nthe petals on this flower are red with yellow tips.\nthis flower is red and yellow in color, with petals that are yellow at the tips.\nthis flower is orange and yellow in color, and has petals that are yellow on the tip.\na large flower with pointy red and yellow pedals and a large brown center.\nthis flower has orange petals that turn orange at the tip, the center of the flower holds very brown stamen.\nthis flower has petals that are red and has yellow tips\nthis is a red flower with yellow on the tips of the petals and a red pistil.\n',
#  'the petals of this flower are red and yellow with a long stigma\nthe flower has petals that are red with yellow tips.\nthis flower has petals that are red with yellow tips\nthe petals of the flower are red with yellow tips and have a red center.\nthis flower is yellow and pink in color, with petals that are yellow on the tips.\nthe flower on this particular picture has petals as well as a sepal.\nthe petals are bright red with yellow tips and dark red veins and the stamen are clustered and dark red.\na distinctive flower with a large circular red center, and petals that start red and turn to yellow at the tips.\nthis flower has petals that are red and has yellow tips\nthis flower is pink and yellow in color, and has petals that are yellow on the tips.\n',
#  'a group of red flowers with yellow tipped petals accompanied by maroon anther filaments.\nthe flower has oval shaped petals that are smaller in size and red in color with yellow patches\nthis flower has large red petals with yellow tips on the end and red stamen in the center\nthe flower shown has pink and yellow petals with red and yellow stamen\nthis flower is pink and yellow in color, with petals that are oval shaped and multi colored.\nthe petals of the flower are red in color and are tipped with yellow.\nthis asymmetrical flower has many small red petals with yellow tips, and a wide center.\nthis flower has red petals that are bright yellow at the tips.\nthis flower has petals that are red and has yellow tips\nthis flower has long red petals whose edges are rounded and yellow.\n',
#  'this flower has a yellow and brown center surrounded by long thin red petals with round yellow tips.\nthe petals are small and pointed and range from reddish orange at the center to yellow at the tip while the stamen and stigma are yellow and brown.\nthis flower is pink and yellow in color, with petals that are yellow at the tips.\nthis flower has petals that are red with yellow tips\nthe petals on this flower are red with yellow tips.\nthis flower has petals that are red and has yellow tips\nthis flower has long red petals whose tapered edges are yellow.\na flower with long and narrow petals that are red with yellow tips.\nthe petals of the flower have bright yellow tips, and the base of the petals are a vibrant orange color.\nthis flower has small oblong petals that are red with yellow tips.\n',
#  'this flower is pink and yellow in color, with petals that are yellow at the tips.\nthis flower has a bright red and yellow color scheme on its petals.\nthe flowers has a lot of petals that are mostly red in color towards the center but yellow towards the edges.\nthis flower has a red center surrounded by long red petals with tapered yellow tips.\na large red flower whose numerous petals have yellow tips.\nthis flower is pink and yellow in color, with multi colored petals.\nthe flower on this particular picture has petals as well as a sepal.\nthis flower has petals that are red and has yellow tips\nthis flower has long thin red petals with tapered yellow tips.\nthis flower has slender petals that are red in the body and yellow at the tips; it has a broad red pistil with yellow stamens.\n',
#  'the petals on this flower are red with yellow tips.\nthe petals are slim but broad, and they are tinted yellow at the edges and red towards the middle.\nsepals are green in color,petals are pink an yellow in color\nthis flower is pink and yellow in color, with petals that are yellow on the tips.\nthis sun-shaped flower has beautiful red petals with yellow edges and a bunch of stamens.\nthis flower has long red petals which have pointed, pronounced yellow tips.\nthis flower is pink and yellow in color, with petals that are yellow on the tips.\nthis flower has petals that are orange and has yellow tips\na flower with red petals that are yellow at their tips that surround a large dark colored ovule.\nthis exotic pink flower lies on the ground with each of its petals dipped in sunshine yellow.\n',
#  'this flower has yellow and red petals with red stamen and yellow pistil.\nthis flower is red and yellow in color, with petals that are yellow on the tips.\nthis flower has petals that are red with yellow edges and stamen\na yellow and orange flower with a green pedicel and yellow stamen.\nthis flower has petals that are red with yellow tips and yellow stamen.\nthis flower is white and red in color, and has petals that are yellow along the edges.\nthis flower has a ray-like configuration of petals that are red with yellow tips.\nthis flower has stamen that are red and yellow with petals that are red at the base and yellow near the ends.\nthis flower has red petals with yellow tips and many stamen\nthis flower has dark red petals with yellow tips forming a line around the outside, and a pronounced yellow pistil.\n',
#  'the flower has red petals with yellow tips and a green pedicel\nthis flower has long petals in a radiating pattern that begin bright red toward the center and fade out to yellow.\nthis flower has thin peach colored petals with tapered yellow tips.\na flower with red and yellow petals also with maroon anther filaments.\nthis flower is red and yellow in color, and has petals that are curved down.\nthis flower has purple and yellow petals as well as a green pedicel.\nthis flower has petals that are red and has yellow tips\nthis flower has red petals with yellow tips and yellow filament with red anther.\nthis flower has orange and salmon colored petals with yellow tips, a yellow ovule and red in its center.\nthis flowers long petals change from dark red to yellow as you move to the tip and it has a cottony poof of same colored stamen in the center.\n',
#  "a multi flower with color, with red, yellow and pink\nthis flower has a red petals which have yellow tips.\nthe flower is made of elongated petals that are orange with yellow tips.\nthis flower has groups of long think red petals with yellow tips around a center of yellow, red and brown stamen.\nthis flower features a large red yellow centered ovary surrounded by elongated red leaves with yellow tips.\nthis flower has narrow petals with two points on each and are pink with yellow tips.\nthis flower, being suckled by a bee is a nice rounded arrangement of pedals. it's sepal area is very wide and noticeable.\nthe flower has petals that are soft, smooth and has yellow tip that is gradually getting reddish brown towards the center and also the petals are arranged in disc like manner around stamens\nthis flower has petals that are red and has a yellow tip\nthis flower has a single layer of red petals with yellow tips arranged in a ring\n",
#  'the petals on this flower are red with yellow tips.\nthis flower is red and yellow in color, with petals that are multi colored.\nthis flower has petals that are red with yellow tips\ntwo flowers with pink petals and yellow tips on end of each petal and a large deep colored stamen.\nthis blossom has red petals with yellow edges, the center is maroon on the outside edges and yellow in the center.\nthis flower has petals that are red and has yellow tips\nthis flower is pink and yellow in color, and has petals that are yellow on the tips.\nthis flower has wide pink petals which divide out into three yellow tips; the large ovule contains many short yellow stamens with dark red anthers.\nthe bright pink and yellow petals surround a large group of short darker colored stamen.\npistil and stamen vary in color from dark red to yellow and the petals are pink closest to the center, yellow furthest from the center.\n']

# %%
import gensim.downloader as api
glove_model = api.load('glove-twitter-200')

# %%
def test_image(text,num):
    test_embeddings = np.zeros((1,200),dtype=np.float32)

    x = text.lower()
    x = x.replace(" ","")
    count = 0
    for t in x:
        try:
            test_embeddings[0] += glove_model[t]
            count += 1
        except:
            #print(t)
            pass
    print(test_embeddings)
    if count != 0:
        test_embeddings[0] /= count
    else:
        return
    test_embeddings =  np.repeat(test_embeddings,[28],axis=0)
    noise = tf.random.normal([28, 100])
    save_images(num,noise,test_embeddings)

# %%
import IPython

# %%
test_image("this flower is yellow in color with oval shaped petals", 1)
IPython.display.Image('./Data/datasets/output/train-1.png')
# Out:
# [[ 8.8488274e+00 -6.3596711e+00  7.2783966e+00 -4.8506737e+00
#   -2.8250167e+00 -7.1752608e-01 -2.9842371e+01 -5.5355630e+00
#   -5.1024184e+00  1.5407039e+01 -6.9949632e+00 -1.1839816e+01
#   -6.1694674e+00  4.8820624e+00 -7.1881633e+00 -6.1490531e+00
#   -1.2922376e+01 -2.8915164e+00 -2.1194096e+01  1.6911091e+01
#   -3.1744752e+00 -9.2550917e+00  2.4651951e+01  1.3993286e+01
#    1.0590823e+01 -6.1763893e+01 -8.2646284e+00 -8.6736679e+00
#    2.3534412e+01  1.3863489e+01 -1.4661982e+01 -9.3478432e+00
#   -9.4071846e+00  5.6499273e-01  2.0107777e+01 -3.5452217e-01
#   -7.8760881e+00 -6.5186172e+00 -2.4814938e+01  8.9871750e+00
#   -4.9516762e+01  8.5098705e+00  1.7526638e+01 -4.2491198e-01
#   -5.9351044e+00  8.2808876e-01  1.9504803e-01 -1.3530692e+01
#    6.0162277e+00 -1.3190752e+01  1.0965534e+00  7.3055387e-01
#   -1.0252500e+00  9.2277517e+00  3.5739169e+00  3.5809753e+00
#    9.2840302e-01 -5.9725924e+00  2.7216303e+00 -9.6437597e+00
